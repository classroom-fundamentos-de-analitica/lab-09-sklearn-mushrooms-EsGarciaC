# %%
import pandas as pd

train_df = pd.read_csv("train_dataset.csv")
test_df = pd.read_csv("test_dataset.csv")

# %% [markdown]
# # Dataframe inspection

# %%
train_df.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           y         n       t    p               f
# 1    e         f           y         g       t    n               f
# 2    e         x           y         y       t    a               f
# 3    e         x           s         w       f    n               f
# 4    e         x           f         n       t    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          p  ...                        s
# 1            c         b          p  ...                        s
# 2            c         b          k  ...                        s
# 3            w         b          k  ...                        s
# 4            c         b          p  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      g                      g         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      p                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 k          y       d
# 2           o         p                 n          n       m
# 3           o         e                 k          a       g
# 4           o         p                 n          v       d
#
# [5 rows x 23 columns]

# %%
test_df.shape, train_df.shape
# Out:
# ((2031, 23), (6093, 23))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6093 entries, 0 to 6092
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      6093 non-null   object
#  1   cap_shape                 6093 non-null   object
#  2   cap_surface               6093 non-null   object
#  3   cap_color                 6093 non-null   object
#  4   bruises                   6093 non-null   object
#  5   odor                      6093 non-null   object
#  6   gill_attachment           6093 non-null   object
#  7   gill_spacing              6093 non-null   object
#  8   gill_size                 6093 non-null   object
#  9   gill_color                6093 non-null   object
#  10  stalk_shape               6093 non-null   object
#  11  stalk_root                6093 non-null   object
#  12  stalk_surface_above_ring  6093 non-null   object
#  13  stalk_surface_below_ring  6093 non-null   object
#  14  stalk_color_above_ring    6093 non-null   object
#  15  stalk_color_below_ring    6093 non-null   object
#  16  veil_type                 6093 non-null   object
#  17  veil_color                6093 non-null   object
#  18  ring_number               6093 non-null   object
#  19  ring_type                 6093 non-null   object
#  20  spore_print_color         6093 non-null   object
#  21  population                6093 non-null   object
#  22  habitat                   6093 non-null   object
# dtypes: object(23)
# memory usage: 1.1+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2031 entries, 0 to 2030
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      2031 non-null   object
#  1   cap_shape                 2031 non-null   object
#  2   cap_surface               2031 non-null   object
#  3   cap_color                 2031 non-null   object
#  4   bruises                   2031 non-null   object
#  5   odor                      2031 non-null   object
#  6   gill_attachment           2031 non-null   object
#  7   gill_spacing              2031 non-null   object
#  8   gill_size                 2031 non-null   object
#  9   gill_color                2031 non-null   object
#  10  stalk_shape               2031 non-null   object
#  11  stalk_root                2031 non-null   object
#  12  stalk_surface_above_ring  2031 non-null   object
#  13  stalk_surface_below_ring  2031 non-null   object
#  14  stalk_color_above_ring    2031 non-null   object
#  15  stalk_color_below_ring    2031 non-null   object
#  16  veil_type                 2031 non-null   object
#  17  veil_color                2031 non-null   object
#  18  ring_number               2031 non-null   object
#  19  ring_type                 2031 non-null   object
#  20  spore_print_color         2031 non-null   object
#  21  population                2031 non-null   object
#  22  habitat                   2031 non-null   object
# dtypes: object(23)
# memory usage: 365.1+ KB

# %% [markdown]
# There appears to be no nulls inside the dataset

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# get the target column and the rest of the data separated
y_train = train_df['type']
X_train = train_df.drop(columns=['type'])

y_test = test_df['type']
X_test = test_df.drop(columns=['type'])

# %%
hot_encoder = OneHotEncoder()
X_train_encoded = hot_encoder.fit_transform(X_train)
X_test_encoded = hot_encoder.transform(X_test)

X_train_encoded
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 134046 stored elements and shape (6093, 117)>

# %% [markdown]
# ### Only need to encode label for the XGBClassifier

# %%
label_encoder = LabelEncoder()
Y_train_encoded = label_encoder.fit_transform(y_train)
Y_test_encoded = label_encoder.fit_transform(y_test)
Y_train_encoded
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %% [markdown]
# ## functions like a random forest classifier

# %%
from xgboost import XGBClassifier

model = XGBClassifier(                    
    alpha=0.1,                   
    subsample=0.8,     
    colsample_bytree=0.6,  
    objective='binary:logistic',
    max_depth=14,             
    min_child_weight=7,         
    gamma=1e-6,                
    #random_state=42,                 
    n_estimators=100
    )

XGB = model.fit(
    X_train_encoded, 
    Y_train_encoded, 
    eval_set=[(X_test_encoded, Y_test_encoded)])
# Out:
# [0]	validation_0-logloss:0.45237
# [1]	validation_0-logloss:0.31514
# [2]	validation_0-logloss:0.22489
# [3]	validation_0-logloss:0.16315
# [4]	validation_0-logloss:0.12079
# [5]	validation_0-logloss:0.09306
# [6]	validation_0-logloss:0.07106
# [7]	validation_0-logloss:0.05578
# [8]	validation_0-logloss:0.04540
# [9]	validation_0-logloss:0.03641
# [10]	validation_0-logloss:0.03007
# [11]	validation_0-logloss:0.02595
# [12]	validation_0-logloss:0.02293
# [13]	validation_0-logloss:0.01974
# [14]	validation_0-logloss:0.01715
# [15]	validation_0-logloss:0.01559
# [16]	validation_0-logloss:0.01467
# [17]	validation_0-logloss:0.01400
# [18]	validation_0-logloss:0.01292
# [19]	validation_0-logloss:0.01250
# [20]	validation_0-logloss:0.01207
# [21]	validation_0-logloss:0.01144
# [22]	validation_0-logloss:0.01076
# [23]	validation_0-logloss:0.01056
# [24]	validation_0-logloss:0.01003
# [25]	validation_0-logloss:0.00992
# [26]	validation_0-logloss:0.00971
# [27]	validation_0-logloss:0.00941
# [28]	validation_0-logloss:0.00901
# [29]	validation_0-logloss:0.00893
# [30]	validation_0-logloss:0.00859
# [31]	validation_0-logloss:0.00852
# [32]	validation_0-logloss:0.00837
# [33]	validation_0-logloss:0.00817
# [34]	validation_0-logloss:0.00813
# [35]	validation_0-logloss:0.00799
# [36]	validation_0-logloss:0.00791
# [37]	validation_0-logloss:0.00775
# [38]	validation_0-logloss:0.00766
# [39]	validation_0-logloss:0.00761
# [40]	validation_0-logloss:0.00752
# [41]	validation_0-logloss:0.00750
# [42]	validation_0-logloss:0.00748
# [43]	validation_0-logloss:0.00739
# [44]	validation_0-logloss:0.00739
# [45]	validation_0-logloss:0.00731
# [46]	validation_0-logloss:0.00724
# [47]	validation_0-logloss:0.00719
# [48]	validation_0-logloss:0.00716
# [49]	validation_0-logloss:0.00710
# [50]	validation_0-logloss:0.00705
# [51]	validation_0-logloss:0.00707
# [52]	validation_0-logloss:0.00703
# [53]	validation_0-logloss:0.00703
# [54]	validation_0-logloss:0.00696
# [55]	validation_0-logloss:0.00696
# [56]	validation_0-logloss:0.00694
# [57]	validation_0-logloss:0.00687
# [58]	validation_0-logloss:0.00688
# [59]	validation_0-logloss:0.00684
# [60]	validation_0-logloss:0.00678
# [61]	validation_0-logloss:0.00672
# [62]	validation_0-logloss:0.00673
# [63]	validation_0-logloss:0.00668
# [64]	validation_0-logloss:0.00662
# [65]	validation_0-logloss:0.00660
# [66]	validation_0-logloss:0.00659
# [67]	validation_0-logloss:0.00660
# [68]	validation_0-logloss:0.00653
# [69]	validation_0-logloss:0.00651
# [70]	validation_0-logloss:0.00652
# [71]	validation_0-logloss:0.00648
# [72]	validation_0-logloss:0.00647
# [73]	validation_0-logloss:0.00641
# [74]	validation_0-logloss:0.00641
# [75]	validation_0-logloss:0.00638
# [76]	validation_0-logloss:0.00639
# [77]	validation_0-logloss:0.00640
# [78]	validation_0-logloss:0.00641
# [79]	validation_0-logloss:0.00642
# [80]	validation_0-logloss:0.00642
# [81]	validation_0-logloss:0.00638
# [82]	validation_0-logloss:0.00637
# [83]	validation_0-logloss:0.00633
# [84]	validation_0-logloss:0.00631
# [85]	validation_0-logloss:0.00630
# [86]	validation_0-logloss:0.00630
# [87]	validation_0-logloss:0.00627
# [88]	validation_0-logloss:0.00627
# [89]	validation_0-logloss:0.00628
# [90]	validation_0-logloss:0.00628
# [91]	validation_0-logloss:0.00628
# [92]	validation_0-logloss:0.00628
# [93]	validation_0-logloss:0.00629
# [94]	validation_0-logloss:0.00626
# [95]	validation_0-logloss:0.00626
# [96]	validation_0-logloss:0.00622
# [97]	validation_0-logloss:0.00621
# [98]	validation_0-logloss:0.00622
# [99]	validation_0-logloss:0.00620

# %%
y_pred_train = XGB.predict(X_train_encoded)

# %%
y_pred_test = XGB.predict(X_test_encoded)

# %%
train_accuracy = accuracy_score(Y_train_encoded, y_pred_train)
print(f'Accuracy of training data: {train_accuracy:.2f}')

test_accuracy = accuracy_score(Y_test_encoded, y_pred_test)
print(f'Accuracy of testing data: {test_accuracy:.2f}')
# Out:
# Accuracy of training data: 1.00
# Accuracy of testing data: 1.00

# %% [markdown]
# This class is created because the normal RandomForestClassifier does not support un-encoded data

# %% [markdown]
# ## Normal random forest

# %%
random_forest_classif = RandomForestClassifier(n_estimators=100, random_state=53)
random_forest_classif.fit(X_train_encoded, Y_train_encoded)
# Out:
# RandomForestClassifier(random_state=53)

# %%
y_train_pred = random_forest_classif.predict(X_train_encoded)
y_test_pred = random_forest_classif.predict(X_test_encoded)

# %%
train_accuracy = accuracy_score(Y_train_encoded, y_train_pred)
print(f'Accuracy of training data: {train_accuracy:.2f}')
test_accuracy = accuracy_score(Y_test_encoded, y_test_pred)
print(f'Accuracy of training data: {test_accuracy:.2f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\sklearn\metrics\_classification.py:131, in _check_targets(y_true, y_pred)
#     130 try:
# --> 131     unique_values = _union1d(y_true, y_pred, xp)
#     132 except TypeError as e:
#     133     # We expect y_true and y_pred to be of the same data type.
#     134     # If `y_true` was provided to the classifier as strings,
#     135     # `y_pred` given by the classifier will also be encoded with
#     136     # strings. So we raise a meaningful error
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\sklearn\utils\_array_api.py:184, in _union1d(a, b, xp)
#     183 if _is_numpy_namespace(xp):
# --> 184     return xp.asarray(numpy.union1d(a, b))
#     185 assert a.ndim == b.ndim == 1
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\numpy\lib\_arraysetops_impl.py:1142, in union1d(ar1, ar2)
#    1115 """
#    1116 Find the union of two arrays.
#    1117
#    (...)
#    1140 array([1, 2, 3, 4, 6])
#    1141 """
# -> 1142 return unique(np.concatenate((ar1, ar2), axis=None))
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\numpy\lib\_arraysetops_impl.py:289, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     288 if axis is None:
# --> 289     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     290                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None)
#     291     return _unpack_tuple(ret)
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\numpy\lib\_arraysetops_impl.py:356, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis)
#     355 else:
# --> 356     ar.sort()
#     357     aux = ar
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_accuracy = accuracy_score(y_train, y_train_pred)
#       2 print(f'Accuracy of training data: {train_accuracy:.2f}')
#       3 test_accuracy = accuracy_score(y_test, y_test_pred)
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\sklearn\metrics\_classification.py:231, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     229 xp, _, device = get_namespace_and_device(y_true, y_pred, sample_weight)
#     230 # Compute accuracy for each possible representation
# --> 231 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     232 check_consistent_length(y_true, y_pred, sample_weight)
#     233 if y_type.startswith("multilabel"):
#
# File c:\Users\Esteban\github-classroom\classroom-fundamentos-de-analitica\lab-09-sklearn-mushrooms-EsGarciaC\.venv\Lib\site-packages\sklearn\metrics\_classification.py:137, in _check_targets(y_true, y_pred)
#     131     unique_values = _union1d(y_true, y_pred, xp)
#     132 except TypeError as e:
#     133     # We expect y_true and y_pred to be of the same data type.
#     134     # If `y_true` was provided to the classifier as strings,
#     135     # `y_pred` given by the classifier will also be encoded with
#     136     # strings. So we raise a meaningful error
# --> 137     raise TypeError(
#     138         "Labels in y_true and y_pred should be of the same type. "
#     139         f"Got y_true={xp.unique(y_true)} and "
#     140         f"y_pred={xp.unique(y_pred)}. Make sure that the "
#     141         "predictions provided by the classifier coincides with "
#     142         "the true labels."
#     143     ) from e
#     144 if unique_values.shape[0] > 2:
#     145     y_type = "multiclass"
#
# TypeError: Labels in y_true and y_pred should be of the same type. Got y_true=['e' 'p'] and y_pred=[0 1]. Make sure that the predictions provided by the classifier coincides with the true labels.

# %%
import pickle

# save model XGB
# with open('model.pkl', 'wb') as file:
#     pickle.dump(XGB, file)

# save normal random forest classif
with open('model.pkl', 'wb') as file:
    pickle.dump(random_forest_classif, file)

# Save my custom RFC
# with open('model.pkl', 'wb') as file:
#     pickle.dump(custom_RFC, file)
